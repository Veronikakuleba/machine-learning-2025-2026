# %% [markdown]
# ## Zadanie
#
# Mamy tekst CSV zapisany jako zwykły string.
#
# Waszym celem jest:
#
# 1. rozdzielić tekst na linie,
# 2. wyciągnąć nagłówki,
# 3. zbudować listę słowników `products`,
# 4. policzyć średnią cenę produktów droższych niż 10.

# %%
# Tekst CSV zapisany jako zwykły string
csv_text = """product,price
apple,8
banana,12
milk,15
bread,9
cheese,20
"""

# %%
# TODO:
# Rozdziel tekst na linie i zapisz wynik do zmiennej lines

lines = ...

print(lines)
# Out:
# Ellipsis

# %%
# TODO:
# Pierwsza linia zawiera nagłówki kolumn
# Rozdziel ją po przecinku i zapisz do zmiennej headers

headers = ...

print(headers)
# Out:
# Ellipsis

# %%
# Tworzymy pustą listę na produkty
products = []

# %%
# TODO:
# Przejdź po liniach od drugiej linijki (bez nagłówka)
# i wypisz każdą linię

for line in ...:
    print(line)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 5
#       1 # TODO:
#       2 # Przejdź po liniach od drugiej linijki (bez nagłówka)
#       3 # i wypisz każdą linię
# ----> 5 for line in ...:
#       6     print(line)
#
# TypeError: 'ellipsis' object is not iterable

# %%
# TODO:
# Dla każdej linii:
# - pomiń pustą linię
# - rozdziel dane po przecinku
# - wypisz values

for line in lines[1:]:
    if ...:
        continue

    values = ...
    print(values)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 7
#       1 # TODO:
#       2 # Dla każdej linii:
#       3 # - pomiń pustą linię
#       4 # - rozdziel dane po przecinku
#       5 # - wypisz values
# ----> 7 for line in lines[1:]:
#       8     if ...:
#       9         continue
#
# TypeError: 'ellipsis' object is not subscriptable

# %%
# TODO:
# Zbuduj słownik dla jednego produktu
# price ma być typu int

for line in lines[1:]:
    if line.strip() == "":
        continue

    values = line.split(",")

    product = {}

    for i in range(len(headers)):
        if headers[i] == "price":
            product[headers[i]] = ...
        else:
            product[headers[i]] = ...

    print(product)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 5
#       1 # TODO:
#       2 # Zbuduj słownik dla jednego produktu
#       3 # price ma być typu int
# ----> 5 for line in lines[1:]:
#       6     if line.strip() == "":
#       7         continue
#
# TypeError: 'ellipsis' object is not subscriptable

# %%
# TODO:
# Teraz dodaj każdy słownik do listy products

products = []

for line in lines[1:]:
    if line.strip() == "":
        continue

    values = line.split(",")

    product = {}

    for i in range(len(headers)):
        if headers[i] == "price":
            product[headers[i]] = int(values[i])
        else:
            product[headers[i]] = values[i]

    ...

print(products)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 6
#       1 # TODO:
#       2 # Teraz dodaj każdy słownik do listy products
#       4 products = []
# ----> 6 for line in lines[1:]:
#       7     if line.strip() == "":
#       8         continue
#
# TypeError: 'ellipsis' object is not subscriptable

# %%
# TODO:
# Policz sumę cen produktów droższych niż 10
# oraz ile takich produktów jest

total = 0
count = 0

for product in products:
    if product["price"] > ...:
        total = total + ...
        count = count + ...

print("Suma:", total)
print("Liczba produktów:", count)
# Out:
# Suma: 0
# Liczba produktów: 0

# %%
# TODO:
# Policz średnią i wypisz wynik

average = total / count
print("Średnia cena produktów droższych niż 10:", average)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[10], line 4
#       1 # TODO:
#       2 # Policz średnią i wypisz wynik
# ----> 4 average = total / count
#       5 print("Średnia cena produktów droższych niż 10:", average)
#
# ZeroDivisionError: division by zero
