# %%
# Tekst CSV zapisany jako zwykły string wielolinijkowy
csv_text = """name,grade
Ala,4
Ola,5
Jan,3
Piotr,5
Kasia,2
"""

# TODO: podziel tekst na linie
lines = None

# TODO: pobierz nagłówki z pierwszej linii
headers = None

# TODO: utwórz pustą listę students
students = None

# TODO: przejdź po liniach od drugiej do końca
for line in ...:

    # TODO: pomiń puste linie
    if ...:
        continue

    # TODO: rozdziel linię po przecinku
    values = ...

    # TODO: utwórz pusty słownik dla jednego studenta
    student = ...

    # TODO: przejdź po indeksach nagłówków
    for i in ...:

        # TODO: jeśli nagłówek to "grade", zamień wartość na int
        if ...:
            student[headers[i]] = ...

        # TODO: w przeciwnym razie zapisz zwykły tekst
        else:
            student[headers[i]] = ...

    # TODO: dodaj słownik student do listy students
    ...

# TODO: utwórz zmienną sumującą wszystkie oceny
total_grade = ...

# TODO: utwórz licznik studentów z oceną >= 4
count_ge4 = ...

# TODO: utwórz pustą listę grades
grades = ...

# TODO: utwórz pustą listę top_students
top_students = ...

# TODO: przejdź po każdym studencie
for student in ...:

    # TODO: dodaj ocenę do listy grades
    ...

    # TODO: dodaj ocenę do sumy
    ...

    # TODO: jeśli ocena >= 4, zwiększ licznik
    if ...:
        ...

    # TODO: jeśli ocena == 5, dodaj imię do top_students
    if ...:
        ...

# TODO: policz średnią ocen
mean_grade = ...

# TODO: policz rozstęp ocen
grade_range = ...

# TODO: policz procent studentów z oceną >= 4
share_ge4 = ...

# Wyświetlamy wyniki
print("Studenci:", students)
print("Średnia ocen:", mean_grade)
print("Rozstęp ocen:", grade_range)
print("Liczba studentów z oceną >= 4:", count_ge4)
print("Procent studentów z oceną >= 4:", share_ge4)
print("Studenci z oceną 5:", top_students)
